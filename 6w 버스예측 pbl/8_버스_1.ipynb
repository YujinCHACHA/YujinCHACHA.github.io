# %% [markdown]
# # 버스 1

# %% [markdown]
# ## 0.준비

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 49 not upgraded.
# Need to get 9,604 kB of archives.
# After this operation, 29.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-nanum all 20170925-1 [9,604 kB]
# Fetched 9,604 kB in 1s (9,128 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 155653 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20170925-1_all.deb ...
# Unpacking fonts-nanum (20170925-1) ...
# Setting up fonts-nanum (20170925-1) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')

from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
# Out:
# Mounted at /content/drive

# %%
train = pd.read_csv('/content/drive/MyDrive/Dacon/6w 버스예측 pbl/train.csv')
test = pd.read_csv('/content/drive/MyDrive/Dacon/6w 버스예측 pbl/test.csv')
submission = pd.read_csv('/content/drive/MyDrive/Dacon/6w 버스예측 pbl/sample_submission.csv')

# %%
train.head(3)
# Out:
#    id        date   route_id    vh_id route_nm  now_latitude  now_longitude  \
# 0   0  2019-10-15  405136001  7997025    360-1     33.456267     126.551750
# 1   1  2019-10-15  405136001  7997025    360-1     33.457724     126.554014
# 2   2  2019-10-15  405136001  7997025    360-1     33.458783     126.557353
#
#   now_station now_arrive_time  distance next_station  next_latitude  \
# 0     제주대학교입구             06시     266.0         제대마을      33.457724
# 1        제대마을             06시     333.0        제대아파트      33.458783
# 2       제대아파트             06시     415.0        제주대학교      33.459893
#
#    next_longitude  next_arrive_time
# 0      126.554014                24
# 1      126.557353                36
# 2      126.561624                40

# %%
test.head(3)
# Out:
#        id        date   route_id    vh_id route_nm  now_latitude  \
# 0  210457  2019-10-29  405136001  7997025    360-1     33.457724
# 1  210458  2019-10-29  405136001  7997025    360-1     33.458783
# 2  210459  2019-10-29  405136001  7997025    360-1     33.478867
#
#    now_longitude  now_station now_arrive_time  distance next_station  \
# 0     126.554014         제대마을             07시     333.0        제대아파트
# 1     126.557353        제대아파트             07시     415.0        제주대학교
# 2     126.483833  한라중학교/부영아파트             08시     417.0      대림2차아파트
#
#    next_latitude  next_longitude
# 0      33.458783      126.557353
# 1      33.459893      126.561624
# 2      33.478850      126.488350

# %%
submission.head(3)
# Out:
#        id  next_arrive_time
# 0  210457                 0
# 1  210458                 0
# 2  210459                 0

# %% [markdown]
# ## 1.데이터 살펴보기

# %%
train
# Out:
#             id        date   route_id    vh_id route_nm  now_latitude  \
# 0            0  2019-10-15  405136001  7997025    360-1     33.456267
# 1            1  2019-10-15  405136001  7997025    360-1     33.457724
# 2            2  2019-10-15  405136001  7997025    360-1     33.458783
# 3            3  2019-10-15  405136001  7997025    360-1     33.479705
# 4            4  2019-10-15  405136001  7997025    360-1     33.485662
# ...        ...         ...        ...      ...      ...           ...
# 210452  210452  2019-10-28  405328102  7983486    281-2     33.255783
# 210453  210453  2019-10-28  405328102  7983486    281-2     33.248595
# 210454  210454  2019-10-28  405328102  7983486    281-2     33.251891
# 210455  210455  2019-10-28  405328102  7983486    281-2     33.251084
# 210456  210456  2019-10-28  405328102  7983486    281-2     33.248487
#
#         now_longitude   now_station now_arrive_time  distance  \
# 0          126.551750       제주대학교입구             06시     266.0
# 1          126.554014          제대마을             06시     333.0
# 2          126.557353         제대아파트             06시     415.0
# 3          126.543811     남국원(아라방면)             06시     578.0
# 4          126.494923           도호동             07시     374.0
# ...               ...           ...             ...       ...
# 210452     126.577450          비석거리             21시     528.0
# 210453     126.568527         동문로터리             21시     280.0
# 210454     126.560303  서귀포시 구 버스터미널             21시     114.0
# 210455     126.559551     아랑조을거리 입구             21시     223.0
# 210456     126.511195       대륜동주민센터             21시     189.0
#
#            next_station  next_latitude  next_longitude  next_arrive_time
# 0                  제대마을      33.457724      126.554014                24
# 1                 제대아파트      33.458783      126.557353                36
# 2                 제주대학교      33.459893      126.561624                40
# 3       제주여자중고등학교(아라방면)      33.484860      126.542928                42
# 4                   은남동      33.485822      126.490897                64
# ...                 ...            ...             ...               ...
# 210452            삼아아파트      33.251896      126.574417                96
# 210453      매일올레시장 7번입구      33.249753      126.565959                50
# 210454        아랑조을거리 입구      33.251084      126.559551                16
# 210455            평생학습관      33.249504      126.558068                38
# 210456  서귀포버스터미널(가상정류소)      33.249091      126.509224                24
#
# [210457 rows x 14 columns]

# %%
train[['next_latitude',	'next_longitude']][:5].values
# Out:
# array([[ 33.457724, 126.554014],
#        [ 33.458783, 126.557353],
#        [ 33.459893, 126.561624],
#        [ 33.48486 , 126.542928],
#        [ 33.485822, 126.490897]])

# %%
center = [33.35, 126.5]

# %%
import folium

locations = train[['next_latitude',	'next_longitude']][:5].values

m = folium.Map(location=center, zoom_start=11, tiles='cartodbpositron',)

for i, location in enumerate(locations):
  folium.Circle(
      radius=50,
      location=location,
      tooltip=train['next_station'].loc[i],
      fill=True
  ).add_to(m)

folium.PolyLine(locations=locations).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#         initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#     &lt;style&gt;#map_7cec4803736c3d4bb497e6c6ed9fb296 {
#         position: relative;
#         width: 100.0%;
#         height: 100.0%;
#         left: 0.0%;
#         top: 0.0%;
#         }
#     &lt;/style&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div class=&quot;folium-map&quot; id=&quot;map_7cec4803736c3d4bb497e6c6ed9fb296&quot; &gt;&lt;/div&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#         var bounds = null;
#
#
#     var map_7cec4803736c3d4bb497e6c6ed9fb296 = L.map(
#         &#x27;map_7cec4803736c3d4bb497e6c6ed9fb296&#x27;, {
#         center: [33.35, 126.5],
#         zoom: 11,
#         maxBounds: bounds,
#         layers: [],
#         worldCopyJump: false,
#         crs: L.CRS.EPSG3857,
#         zoomControl: true,
#         });
#
#
#
#     var tile_layer_b710f907fa0b0dd75e46d9ea7e3704dd = L.tileLayer(
#         &#x27;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&#x27;,
#         {
#         &quot;attribution&quot;: null,
#         &quot;detectRetina&quot;: false,
#         &quot;maxNativeZoom&quot;: 18,
#         &quot;maxZoom&quot;: 18,
#         &quot;minZoom&quot;: 0,
#         &quot;noWrap&quot;: false,
#         &quot;opacity&quot;: 1,
#         &quot;subdomains&quot;: &quot;abc&quot;,
#         &quot;tms&quot;: false
# }).addTo(map_7cec4803736c3d4bb497e6c6ed9fb296);
#
#
#             var circle_0ee9c3363de61dad2a4a9984e2f94c36 = L.circle(
#                 [33.457724, 126.554014],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 50,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_7cec4803736c3d4bb497e6c6ed9fb296);
#
#
#         circle_0ee9c3363de61dad2a4a9984e2f94c36.bindTooltip(
#             `&lt;div&gt;`
#             + `제대마을` + `&lt;/div&gt;`,
#             {&quot;sticky&quot;: true}
#         );
#
#
#
#             var circle_c992308131c17eff9d2eccde1b4432f8 = L.circle(
#                 [33.458783000000004, 126.557353],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 50,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_7cec4803736c3d4bb497e6c6ed9fb296);
#
#
#         circle_c992308131c17eff9d2eccde1b4432f8.bindTooltip(
#             `&lt;div&gt;`
#             + `제대아파트` + `&lt;/div&gt;`,
#             {&quot;sticky&quot;: true}
#         );
#
#
#
#             var circle_2490d47a4803ccdeb0b58dc49d38bce2 = L.circle(
#                 [33.459893, 126.561624],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 50,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_7cec4803736c3d4bb497e6c6ed9fb296);
#
#
#         circle_2490d47a4803ccdeb0b58dc49d38bce2.bindTooltip(
#             `&lt;div&gt;`
#             + `제주대학교` + `&lt;/div&gt;`,
#             {&quot;sticky&quot;: true}
#         );
#
#
#
#             var circle_04d1ed6606e83cc2c6ac419a9d289041 = L.circle(
#                 [33.48486, 126.542928],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 50,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_7cec4803736c3d4bb497e6c6ed9fb296);
#
#
#         circle_04d1ed6606e83cc2c6ac419a9d289041.bindTooltip(
#             `&lt;div&gt;`
#             + `제주여자중고등학교(아라방면)` + `&lt;/div&gt;`,
#             {&quot;sticky&quot;: true}
#         );
#
#
#
#             var circle_a3a59a74f50be71ef3cebc6af8c4c960 = L.circle(
#                 [33.485822, 126.490897],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 50,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_7cec4803736c3d4bb497e6c6ed9fb296);
#
#
#         circle_a3a59a74f50be71ef3cebc6af8c4c960.bindTooltip(
#             `&lt;div&gt;`
#             + `은남동` + `&lt;/div&gt;`,
#             {&quot;sticky&quot;: true}
#         );
#
#
#                 var poly_line_3ae076225f15d7f2013f55aecc1645b8 =

# %% [markdown]
# ## 2.모델링

# %% [markdown]
# ### 1) 데이터 전처리

# %%
# id, date는 안겹치니까 필요 없음
# 범주형 데이터 숫자로 변경

train
# Out:
#             id        date   route_id    vh_id route_nm  now_latitude  \
# 0            0  2019-10-15  405136001  7997025    360-1     33.456267
# 1            1  2019-10-15  405136001  7997025    360-1     33.457724
# 2            2  2019-10-15  405136001  7997025    360-1     33.458783
# 3            3  2019-10-15  405136001  7997025    360-1     33.479705
# 4            4  2019-10-15  405136001  7997025    360-1     33.485662
# ...        ...         ...        ...      ...      ...           ...
# 210452  210452  2019-10-28  405328102  7983486    281-2     33.255783
# 210453  210453  2019-10-28  405328102  7983486    281-2     33.248595
# 210454  210454  2019-10-28  405328102  7983486    281-2     33.251891
# 210455  210455  2019-10-28  405328102  7983486    281-2     33.251084
# 210456  210456  2019-10-28  405328102  7983486    281-2     33.248487
#
#         now_longitude   now_station now_arrive_time  distance  \
# 0          126.551750       제주대학교입구             06시     266.0
# 1          126.554014          제대마을             06시     333.0
# 2          126.557353         제대아파트             06시     415.0
# 3          126.543811     남국원(아라방면)             06시     578.0
# 4          126.494923           도호동             07시     374.0
# ...               ...           ...             ...       ...
# 210452     126.577450          비석거리             21시     528.0
# 210453     126.568527         동문로터리             21시     280.0
# 210454     126.560303  서귀포시 구 버스터미널             21시     114.0
# 210455     126.559551     아랑조을거리 입구             21시     223.0
# 210456     126.511195       대륜동주민센터             21시     189.0
#
#            next_station  next_latitude  next_longitude  next_arrive_time
# 0                  제대마을      33.457724      126.554014                24
# 1                 제대아파트      33.458783      126.557353                36
# 2                 제주대학교      33.459893      126.561624                40
# 3       제주여자중고등학교(아라방면)      33.484860      126.542928                42
# 4                   은남동      33.485822      126.490897                64
# ...                 ...            ...             ...               ...
# 210452            삼아아파트      33.251896      126.574417                96
# 210453      매일올레시장 7번입구      33.249753      126.565959                50
# 210454        아랑조을거리 입구      33.251084      126.559551                16
# 210455            평생학습관      33.249504      126.558068                38
# 210456  서귀포버스터미널(가상정류소)      33.249091      126.509224                24
#
# [210457 rows x 14 columns]

# %%
set(test['now_station'].unique()) - set(train['now_station'].unique())
# Out:
# {'제주한라대학교(종점)'}

# %%
train[train['now_station'] == '제주한라대학교(종점)']
# Out:
# Empty DataFrame
# Columns: [id, date, route_id, vh_id, route_nm, now_latitude, now_longitude, now_station, now_arrive_time, distance, next_station, next_latitude, next_longitude, next_arrive_time]
# Index: []

# %%
test[test['now_station'] == '제주한라대학교(종점)']

# train셋의 now_station과 next_station을 모두 합쳐서 dict로 만들어야 함
# Out:
#           id        date   route_id    vh_id route_nm  now_latitude  \
# 2868  213330  2019-10-29  405136521  7997001   365-21     33.477787
#
#       now_longitude  now_station now_arrive_time  distance next_station  \
# 2868      126.47574  제주한라대학교(종점)             07시     431.0        시티주유소
#
#       next_latitude  next_longitude
# 2868      33.476401      126.479759

# %%
my_list = list(train['route_nm'].unique()) + list(train['now_station'].unique()) + list(train['next_station'].unique())
my_dict = {text : i for i, text in enumerate(my_list)}

# %%
my_dict = {text : i for i, text in enumerate(my_list)}
my_dict
# Out:
# {'201-11': 6,
#  '201-12': 7,
#  '201-13': 8,
#  '201-14': 9,
#  '201-15': 10,
#  '201-16': 11,
#  '201-17': 12,
#  '201-18': 13,
#  '201-21': 14,
#  '201-22': 15,
#  '201-24': 16,
#  '201-26': 17,
#  '201-27': 18,
#  '281-1': 19,
#  '281-2': 20,
#  '360-1': 0,
#  '360-12': 3,
#  '360-2': 1,
#  '360-7': 2,
#  '365-21': 4,
#  '365-22': 5,
#  '911의원': 472,
#  'LH아파트': 602,
#  '가마초등학교': 511,
#  '가흥동': 509,
#  '거로 입구': 552,
#  '견월교': 709,
#  '계룡동': 479,
#  '고도농원': 713,
#  '고래왓': 582,
#  '고망난돌입구': 612,
#  '고산동산(광양방면)': 409,
#  '고산동산(아라방면)': 393,
#  '고성리 구 성산농협': 495,
#  '고성리 성산농협': 565,
#  '고성리제주은행': 638,
#  '고성오일시장': 681,
#  '고으니모르 국립제주박물관': 457,
#  '공업단지 입구': 705,
#  '공천포': 524,
#  '관덕정': 433,
#  '광대왓': 534,
#  '광양': 450,
#  '광양사거리': 418,
#  '광지동': 518,
#  '광치기해변': 564,
#  '교래입구': 696,
#  '구 터미널': 530,
#  '구좌보건지소': 678,
#  '구좌중앙초등학교': 477,
#  '국립제주박물관': 648,
#  '그린카센터': 507,
#  '금붕사': 640,
#  '금산목': 590,
#  '김녕리': 549,
#  '김녕해수욕장': 588,
#  '김녕환승정류장(김녕초등학교)': 548,
#  '꽃동산': 710,
#  '난산입구': 593,
#  '난산입구(성산기상대)': 664,
#  '남국사': 407,
#  '남국원(광양방면)': 411,
#  '남국원(아라방면)': 403,
#  '남녕고등학교': 378,
#  '남서광마을': 390,
#  '남서광마을입구': 389,
#  '남성마을입구': 533,
#  '남원1리사무소': 517,
#  '남원생활체육관': 575,
#  '남원읍사무소': 515,
#  '남원취락구조': 519,
#  '남원포구입구': 516,
#  '남흘동': 474,
#  '노형오거리': 377,
#  '노형초등학교': 452,
#  '농협 하나로마트': 660,
#  '농협주유소': 578,
#  '다호마을': 444,
#  '답다니': 702,
#  '대륜동주민센터': 628,
#  '대림2차아파트': 374,
#  '대섬입구': 550,
#  '대원상동': 604,
#  '대화동': 624,
#  '도호동': 382,
#  '동광양': 453,
#  '동문로터리': 527,
#  '동문성당': 654,
#  '동복리': 585,
#  '동복리관광체험어장': 560,
#  '동복리휴게소': 609,
#  '동부보건소': 576,
#  '동산교': 421,
#  '동성동': 475,
#  '동성마을': 386,
#  '동원산업': 508,
#  '뒤통모루': 522,
#  '뒷빌레': 690,
#  '롯데마트': 402,
#  '마방목지': 706,
#  '만장굴입구': 476,
#  '망장포 입구': 636,
#  '매일올레시장 7번입구': 627,
#  '맹살공원': 635,
#  '명신마을': 423,
#  '무도동': 574,
#  '문서교': 647,
#  '문예회관': 454,
#  '법호촌 온성학교': 698,
#  '법호촌입구': 712,
#  '보목입구': 626,
#  '보성시장': 430,
#  '부영아파트': 429,
#  '북촌다려마을': 559,
#  '북촌리': 558,
#  '북촌리해동': 473,
#  '비석거리': 580,
#  '사라봉': 650,
#  '사라봉오거리': 651,
#  '사회복지법인 춘강': 684,
#  '산열이통입구': 570,
#  '산천단': 685,
#  '산천단 한국폴리텍대학': 711,
#  '삼달교차로': 568,
#  '삼매봉': 632,
#  '삼매봉입구': 601,
#  '삼무공원사거리': 380,
#  '삼성여자고등학교': 620,
#  '삼성초등학교': 449,
#  '삼아아파트': 634,
#  '삼양2동': 554,
#  '삼양검문소': 464,
#  '삼양동주민센터': 666,
#  '삼양초등학교': 555,
#  '상도리 세화고등학교': 677,
#  '상도마을회관': 715,
#  '상원동': 523,
#  '상효입구': 662,
#  '샤인빌리조트입구': 512,
#  '서귀포동부도서관': 717,
#  '서귀포버스터미널': 603,
#  '서귀포버스터미널(가상정류소)': 663,
#  '서귀포산업과학고등학교': 689,
#  '서귀포시 구 버스터미널': 633,
#  '서귀포여자고등학교': 630,
#  '서문시장': 434,
#  '서성동': 577,
#  '서소동': 598,
#  '성산고등학교': 493,
#  '성산고입구삼거리': 491,
#  '성산국민체육센터': 490,
#  '성산농협종합유통센터': 610,
#  '성산리': 639,
#  '성산리 취락구조': 542,
#  '성산리입구': 563,
#  '성산읍사무소': 566,
#  '성산일출봉입구': 541,
#  '성산포 수협': 540,
#  '성산포수협표선지점': 505,
#  '성산항입구': 616,
#  '성산환승정류장(고성리 한국물류)': 496,
#  '성산환승정류장(고성리 회전교차로)': 658,
#  '성판악': 697,
#  '세기아파트': 581,
#  '세천동': 599,
#  '세화2리사무소': 510,
#  '세화고등학교': 680,
#  '세화리구좌농협': 483,
#  '세화리시장2동': 481,
#  '세화환승정류장(세화리)': 482,
#  '송천교': 571,
#  '수농원': 595,
#  '수모루': 629,
#  '수악교': 704,
#  '시민회관': 431,
#  '시티주유소': 442,
#  '시흥리': 488,
#  '시흥리사무소': 489,
#  '신례2리교차로': 579,
#  '신산로': 655,
#  '신산리': 498,
#  '신산환승정류장(성산농협신산지점)': 499,
#  '신성동': 606,
#  '신양리입구': 497,
#  '신천리': 501,
#  '신천리취락구조': 539,
#  '신촌리': 551,
#  '신촌초등학교': 465,
#  '신풍리하동': 500,
#  '신협': 670,
#  '신효': 674,
#  '신효동': 671,
#  '신흥1번지': 617,
#  '신흥교차로': 572,
#  '신흥리취락구조': 596,
#  '씨사이드홈': 537,
#  '아라동주민센터': 412,
#  '아라주공아파트': 397,
#  '아라초등학교': 396,
#  '아랑조을거리 입구': 531,
#  '앞동산': 675,
#  '양지(추모)공원': 687,
#  '어촌계입구': 597,
#  '여 의 물': 631,
#  '연동대림1차아파트': 375,
#  '연동입구': 385,
#  '연동주민센터': 383,
#  '영등물': 561,
#  '영천동주민센터': 692,
#  '오라3동': 405,
#  '오라오거리': 422,
#  '오조리': 661,
#  '오조리 입구': 492,
#  '오조리상동입구': 683,
#  '오조리하동': 682,
#  '오조해녀의집': 494,
#  '오현중고등학교': 553,
#  '오희준 공원': 700,
#  '온평리': 676,
#  '온평초등학교': 567,
#  '용담1동주민센터': 435,
#  '용문마을': 437,
#  '용문마을회관': 438,
#  '용문사거리': 436,
#  '용천마을': 420,
#  '우당도서관': 649,
#  '웃 인다 마을': 417,
#  '원노형': 376,
#  '원당봉': 665,
#  '원당분화원': 463,
#  '월구마을': 406,
#  '월라봉': 672,
#  '월랑마을 남녕고등학교': 424,
#  '월성 마을': 446,
#  '월정리': 546,
#  '월정리 용천동': 547,
#  '위미1리사무소': 637,
#  '위미3리': 520,
#  '위미3리 마을회관': 605,
#  '위미문화의집': 536,
#  '위미초등학교': 535,
#  '으뜸마을': 426,
#  '은남동': 373,
#  '인다마을': 398,
#  '인화초등학교': 455,
#  '입석동': 703,
#  '전경대 입구': 716,
#  '정존마을': 451,
#  '제대마을': 369,
#  '제대아파트': 370,
#  '제원아파트': 381,
#  '제일교 동문시장입구': 653,
#  '제주고등학교/중흥S클래스': 428,
#  '제주국제공항(구제주방면)': 445,
#  '제주국제공항(신제주방면)': 440,
#  '제주국제대학교': 694,
#  '제주대학교': 371,
#  '제주대학교 입구': 416,
#  '제주대학교교육대학': 458,
#  '제주대학교병원': 399,
#  '제주대학교입구': 400,
#  '제주도청 신제주로터리': 384,
#  '제주동중학교': 461,
#  '제주버스터미널': 387,
#  '제주버스터미널(가상정류소)': 718,
#  '제주버스터미널(종점)': 656,
#  '제주시청(광양방면)': 414,
#  '제주시청(아라방면)': 392,
#  '제주여자상업고등학교': 652,
#  '제주여자중고등학교(광양방면)': 413,
#  '제주여자중고등학교(아라방면)': 372,
#  '제주의료원': 686,
#  '제주제일고등학교': 425,
#  '제주중앙여자고등학교(광양방면)': 415,
#  '제주중앙여자고등학교(아라방면)': 395,
#  '제주중학교/제주향교': 447,
#  '제주지방법원(광양방면)': 410,
#  '제주지방법원(아라방면)': 394,
#  '제주컨트리클럽': 707,
#  '제주한라대학교': 719,
#  '제주한라대학교(종점)': 443,
#  '조천리': 556,
#  '조천만세동산': 644,
#  '조천읍사무소': 607,
#  '조천체육관': 557,
#  '조천초등학교': 646,
#  '조천환승정류장(조천리사무소)': 466,
#  '조천환승정류장(조천우체국)': 645,
#  '종달리': 543,
#  '종달초등학교': 487,
#  '종보존연구센터': 521,
#  '종합사격장': 695,
#  '주공 3 4단지': 526,
#  '주암주택': 586,
#  '죽성마을 입구': 404,
#  '중앙로(국민은행)': 448,
#  '중앙로(현대약국)': 432,
#  '중앙로터리': 693,
#  '중흥S클래스아파트': 441,
#  '지경곰': 589,
#  '진드르': 608,
#  '진은동': 614,
#  '창남거리': 525,
#  '천수동': 456,
#  '청소년문화의집': 529,
#  '충혼묘지': 587,
#  '케이티앤지': 401,
#  '탐라도서관': 427,
#  '탐라장애인 종합복지관': 391,
#  '태흥3리': 613,
#  '태흥3리사무소': 573,
#  '태흥초등학교': 514,
#  '토산관광지구입구': 513,
#  '토평 보목입구': 619,
#  '토평마을회관': 691,
#  '평대리동동': 480,
#  '평대리사무소': 641,
#  '평대리서동': 544,
#  '평대초등학교': 642,
#  '평생학습관': 532,
#  '평안전문요양원': 699,
#  '폭낭사거리': 659,
#  '표선오일시장': 506,
#  '표선초등학교': 503,
#  '표선파출소': 623,
#  '표선환승정류장(표선리 제주은행)': 504,
#  '표선환승정류장(표선리사무소)': 622,
#  '하도리': 591,
#  '하도리 개긋물': 679,
#  '하도리 서문동': 583,
#  '하도리동동': 486,
#  '하도리면수동': 485,
#  '하도리창흥동': 592,
#  '하도초등학교': 668,
#  '하례1리입구': 625,
#  '하례환승정류장(하례리입구)': 688,
#  '하천리취락구조': 621,
#  '하천하동': 502,
#  '한국병원': 388,
#  '한동리': 478,
#  '한동리서동': 545,
#  '한라병원': 379,
#  '한라산 둘레길': 714,
#  '한라생태숲': 708,
#  '한라중학교/부영아파트': 408,
#  '한지교차로': 569,
#  '한지동': 538,
#  '함덕농협지소': 468,
#  '함덕리 3구': 469,
#  '함덕리 4구': 657,
#  '함덕리(4구)': 471,
#  '함덕비석거리': 467,
#  '함덕환승정류장(함덕해수욕장)': 470,
#  '해녀박물관입구': 484,
#  '해양연구소': 643,
#  '행원농공단지': 562,
#  '행원리': 584,
#  '현대산부인과': 528,
#  '혼인지입구': 611,
#  '홍랑로입구': 419,
#  '화물청사입구': 439,
#  '화북남문': 460,
#  '화북주공아파트': 462,
#  '화북초등학교': 459,
#  '화성농장': 667,
#  '효돈농협하나로마트': 618,
#  '효돈중학교': 673,
#  '효돈초등학교': 669,
#  '효돈축구공원': 615,
#  '효례교': 600,
#  '흙통': 701,
#  '희진주유소': 594}

# %%
train[['route_nm', 'now_station', 'next_station']] = train[['route_nm', 'now_station', 'next_station']].applymap(lambda x:my_dict[x])

# %%
train.head(3)
# Out:
#    id        date   route_id    vh_id  route_nm  now_latitude  now_longitude  \
# 0   0  2019-10-15  405136001  7997025         0     33.456267     126.551750
# 1   1  2019-10-15  405136001  7997025         0     33.457724     126.554014
# 2   2  2019-10-15  405136001  7997025         0     33.458783     126.557353
#
#    now_station now_arrive_time  distance  next_station  next_latitude  \
# 0          400             06시     266.0           369      33.457724
# 1          369             06시     333.0           370      33.458783
# 2          370             06시     415.0           371      33.459893
#
#    next_longitude  next_arrive_time
# 0      126.554014                24
# 1      126.557353                36
# 2      126.561624                40

# %%
my_dict['제주대학교입구']
# Out:
# 400

# %%
def text_to_time(text:str):
  return int(text[:2])

train['now_arrive_time'] = train['now_arrive_time'].map(text_to_time)
train
# Out:
#             id        date   route_id    vh_id  route_nm  now_latitude  \
# 0            0  2019-10-15  405136001  7997025         0     33.456267
# 1            1  2019-10-15  405136001  7997025         0     33.457724
# 2            2  2019-10-15  405136001  7997025         0     33.458783
# 3            3  2019-10-15  405136001  7997025         0     33.479705
# 4            4  2019-10-15  405136001  7997025         0     33.485662
# ...        ...         ...        ...      ...       ...           ...
# 210452  210452  2019-10-28  405328102  7983486        20     33.255783
# 210453  210453  2019-10-28  405328102  7983486        20     33.248595
# 210454  210454  2019-10-28  405328102  7983486        20     33.251891
# 210455  210455  2019-10-28  405328102  7983486        20     33.251084
# 210456  210456  2019-10-28  405328102  7983486        20     33.248487
#
#         now_longitude  now_station  now_arrive_time  distance  next_station  \
# 0          126.551750          400                6     266.0           369
# 1          126.554014          369                6     333.0           370
# 2          126.557353          370                6     415.0           371
# 3          126.543811          403                6     578.0           372
# 4          126.494923          382                7     374.0           373
# ...               ...          ...              ...       ...           ...
# 210452     126.577450          580               21     528.0           634
# 210453     126.568527          527               21     280.0           627
# 210454     126.560303          633               21     114.0           531
# 210455     126.559551          531               21     223.0           532
# 210456     126.511195          628               21     189.0           663
#
#         next_latitude  next_longitude  next_arrive_time
# 0           33.457724      126.554014                24
# 1           33.458783      126.557353                36
# 2           33.459893      126.561624                40
# 3           33.484860      126.542928                42
# 4           33.485822      126.490897                64
# ...               ...             ...               ...
# 210452      33.251896      126.574417                96
# 210453      33.249753      126.565959                50
# 210454      33.251084      126.559551                16
# 210455      33.249504      126.558068                38
# 210456      33.249091      126.509224                24
#
# [210457 rows x 14 columns]

# %%
def transform_df(df:pd.DataFrame):
  df[['route_nm', 'now_station', 'next_station']] = df[['route_nm', 'now_station', 'next_station']].applymap(lambda x:my_dict[x])

  def text_to_time(text:str):
    return int(text[:2])

  df['now_arrive_time'] = df['now_arrive_time'].map(text_to_time)
  
  return df

# %%
test = transform_df(test)
test
# Out:
#            id        date   route_id    vh_id  route_nm  now_latitude  \
# 0      210457  2019-10-29  405136001  7997025         0     33.457724
# 1      210458  2019-10-29  405136001  7997025         0     33.458783
# 2      210459  2019-10-29  405136001  7997025         0     33.478867
# 3      210460  2019-10-29  405136001  7997025         0     33.478850
# 4      210461  2019-10-29  405136001  7997025         0     33.480700
# ...       ...         ...        ...      ...       ...           ...
# 91769  302350  2019-11-05  405328102  7983486        20     33.493625
# 91770  302351  2019-11-05  405328102  7983486        20     33.495540
# 91771  302352  2019-11-05  405328102  7983486        20     33.498925
# 91772  302353  2019-11-05  405328102  7983486        20     33.500473
# 91773  302354  2019-11-05  405328102  7983486        20     33.499916
#
#        now_longitude  now_station  now_arrive_time  distance  next_station  \
# 0         126.554014          369                7     333.0           370
# 1         126.557353          370                7     415.0           371
# 2         126.483833          408                8     417.0           374
# 3         126.488350          374                8     334.0           375
# 4         126.489933          375                8     550.0           401
# ...              ...          ...              ...       ...           ...
# 91769     126.534764          410               20     272.0           409
# 91770     126.532907          409               20     447.0           414
# 91771     126.530351          414               20     418.0           418
# 91772     126.527103          418               20     140.0           391
# 91773     126.521348          420               20     541.0           656
#
#        next_latitude  next_longitude
# 0          33.458783      126.557353
# 1          33.459893      126.561624
# 2          33.478850      126.488350
# 3          33.480700      126.489933
# 4          33.482077      126.485355
# ...              ...             ...
# 91769      33.495540      126.532907
# 91770      33.498925      126.530351
# 91771      33.500473      126.527103
# 91772      33.500228      126.525625
# 91773      33.499190      126.516324
#
# [91774 rows x 13 columns]

# %% [markdown]
# ### 2) 선형회귀

# %%
train.columns
# Out:
# Index(['id', 'date', 'route_id', 'vh_id', 'route_nm', 'now_latitude',
#        'now_longitude', 'now_station', 'now_arrive_time', 'distance',
#        'next_station', 'next_latitude', 'next_longitude', 'next_arrive_time'],
#       dtype='object')

# %%
features = train.columns[2:-1]
target = train.columns[-1]

# %%
from sklearn.linear_model import LinearRegression

X = train[features]
y = train[target]

model = LinearRegression()

model.fit(X,y)

y_pred = model.predict(test[features])

# %%
plt.plot(y_pred)
plt.show()
# Out:
# findfont: Font family ['NanumBarunGothic'] not found. Falling back to DejaVu Sans.

# %%
submission[target] = y_pred

# %%
# public 50 private 50

submission.to_csv('submission.csv', index=False)

# %% [markdown]
# ### 3) 랜덤포레스트

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor()

model.fit(X,y)

y_pred = model.predict(test[features])

# %%
plt.plot(y_pred)
plt.show()

# %%
submission[target] = y_pred

# %%
# public 40 private 50

submission.to_csv('submission.csv', index=False)

# %% [markdown]
# ## 3.모델 검증

# %% [markdown]
# ### 1) validation셋 구축

# %%
from sklearn.model_selection import train_test_split

X_train, X_valid, y_train, y_valid = train_test_split(X,y, test_size=0.1, shuffle=False)

# %%
X_train
# Out:
#          route_id    vh_id  route_nm  now_latitude  now_longitude  \
# 0       405136001  7997025         0     33.456267     126.551750
# 1       405136001  7997025         0     33.457724     126.554014
# 2       405136001  7997025         0     33.458783     126.557353
# 3       405136001  7997025         0     33.479705     126.543811
# 4       405136001  7997025         0     33.485662     126.494923
# ...           ...      ...       ...           ...            ...
# 189406  405320114  7983038         9     33.550601     126.782022
# 189407  405320114  7983038         9     33.549650     126.778900
# 189408  405320114  7983038         9     33.552287     126.768187
# 189409  405320114  7983038         9     33.555819     126.760293
# 189410  405320114  7983038         9     33.555767     126.754533
#
#         now_station  now_arrive_time  distance  next_station  next_latitude  \
# 0               400                6     266.0           369      33.457724
# 1               369                6     333.0           370      33.458783
# 2               370                6     415.0           371      33.459893
# 3               403                6     578.0           372      33.484860
# 4               382                7     374.0           373      33.485822
# ...             ...              ...       ...           ...            ...
# 189406          547               20     309.0           476      33.549650
# 189407          476               20    1070.0           589      33.552287
# 189408          589               20     834.0           588      33.555819
# 189409          588               20     571.0           475      33.555767
# 189410          475               20     315.0           548      33.555033
#
#         next_longitude
# 0           126.554014
# 1           126.557353
# 2           126.561624
# 3           126.542928
# 4           126.490897
# ...                ...
# 189406      126.778900
# 189407      126.768187
# 189408      126.760293
# 189409      126.754533
# 189410      126.751250
#
# [189411 rows x 11 columns]

# %%
X_valid
# Out:
#          route_id    vh_id  route_nm  now_latitude  now_longitude  \
# 189411  405320114  7983038         9     33.555033     126.751250
# 189412  405320114  7983038         9     33.554383     126.747113
# 189413  405320114  7983038         9     33.551067     126.700217
# 189414  405320114  7983038         9     33.548117     126.695033
# 189415  405320114  7983038         9     33.539982     126.673231
# ...           ...      ...       ...           ...            ...
# 210452  405328102  7983486        20     33.255783     126.577450
# 210453  405328102  7983486        20     33.248595     126.568527
# 210454  405328102  7983486        20     33.251891     126.560303
# 210455  405328102  7983486        20     33.251084     126.559551
# 210456  405328102  7983486        20     33.248487     126.511195
#
#         now_station  now_arrive_time  distance  next_station  next_latitude  \
# 189411          548               20     400.0           549      33.554383
# 189412          549               20     417.0           474      33.555433
# 189413          559               20     588.0           558      33.548117
# 189414          558               20     992.0           473      33.544183
# 189415          657               20     407.0           470      33.541007
# ...             ...              ...       ...           ...            ...
# 210452          580               21     528.0           634      33.251896
# 210453          527               21     280.0           627      33.249753
# 210454          633               21     114.0           531      33.251084
# 210455          531               21     223.0           532      33.249504
# 210456          628               21     189.0           663      33.249091
#
#         next_longitude
# 189411      126.747113
# 189412      126.742933
# 189413      126.695033
# 189414      126.685467
# 189415      126.669136
# ...                ...
# 210452      126.574417
# 210453      126.565959
# 210454      126.559551
# 210455      126.558068
# 210456      126.509224
#
# [21046 rows x 11 columns]

# %% [markdown]
# ### 2) 선형회귀 모델 검증

# %%
from sklearn.metrics import mean_squared_error

def rmse(pred, real):
  return mean_squared_error(pred, real)**0.5

# %%
model = LinearRegression()

model.fit(X_train,y_train)

y_pred = model.predict(X_valid)

lr_rmse = rmse(y_pred, y_valid)
lr_rmse
# Out:
# 72.47020299658232

# %% [markdown]
# ### 3) 랜덤포레스트 모델 검증

# %%
model = RandomForestRegressor()

model.fit(X_train,y_train)

y_pred = model.predict(X_valid)

rf_rmse = rmse(y_pred, y_valid)
rf_rmse
# Out:
# 57.241707163401195

# %%
lr_rmse/rf_rmse
# Out:
# 1.2660384636976343

# %%
50/40
# Out:
# 1.25

# %% [markdown]
# ## 4.EDA - target

# %% [markdown]
# ### 1) 버스 운행시간 그래프

# %%
train['next_arrive_time'].plot(figsize=(20,10), alpha=0.4)

plt.title('버스 운행시간')
plt.xlabel('인덱스')
plt.ylabel('운행시간')

plt.hlines(y = 20, xmin=0, xmax=len(train), colors='red')
plt.hlines(y = 250, xmin=0, xmax=len(train), colors='red')
plt.hlines(y = 600, xmin=0, xmax=len(train), colors='blue')
plt.hlines(y = 2300, xmin=0, xmax=len(train), colors='green')

plt.show()
# Out:
# findfont: Font family ['NanumBarunGothic'] not found. Falling back to DejaVu Sans.
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48260 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49828 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50868 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54665 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44036 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51064 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 45937 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 51064 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 45937 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 49828 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 50868 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 54665 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44036 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 48260 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ### 2) 버스 운행시간 구간 별 횟수 그래프

# %%
a = train[train['next_arrive_time']<20]
b = train[(train['next_arrive_time']>=20) & (train['next_arrive_time']<250)]
c = train[(train['next_arrive_time']>=250) & (train['next_arrive_time']<600)]
d = train[(train['next_arrive_time']>=600) & (train['next_arrive_time']<2300)]
e = train[(train['next_arrive_time']>=2300)]

# %%
x = ['20미만', '20~250', '250~600', '600~2300', '2300이상']
y = [len(a),len(b),len(c),len(d),len(e)]

plt.figure(dpi=150)

plt.title('버스 운행시간 구간 별 횟수')
plt.xlabel('버스 운행시간 구간')
plt.ylabel('횟수')

plt.bar(x,y)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48260 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49828 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50868 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54665 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44036 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44396 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54943 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48120 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47564 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49345 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 48120 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 47564 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 51060 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 49345 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 48260 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 49828 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 50868 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 54665 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44036 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44396 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 54943 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 48324 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ### 3) 버스 운행시간 b구간이 차지하는 비율 그래프

# %%
len(b)/len(train)
# Out:
# 0.9625481689846382

# %%
x = ['b구간', '나머지']
y = [len(b)/len(train), (1-len(b)/len(train))]

plt.figure(dpi=150)

plt.title('버스 운행시간 구간 비율')

plt.pie(y, labels=x)
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48260 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49828 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50868 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54665 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44036 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44396 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48708 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50984 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 45208 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47672 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51648 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44396 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44036 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 45208 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 47672 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 51648 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 48260 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 49828 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 50868 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 54665 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 48708 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 50984 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ### 4) 버스 운행시간 히스토그램

# %%
plt.figure(dpi=150)

plt.title('버스 운행시간 히스토그램')
plt.xlabel('운행시간')
plt.ylabel('횟수')

plt.hist(train[train['next_arrive_time']<600]['next_arrive_time'], bins=20)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48260 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49828 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50868 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54665 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44036 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 55176 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 53664 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44536 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47016 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54943 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 50868 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 54665 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44036 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 54943 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 48260 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 49828 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 55176 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 53664 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44536 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 47016 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ### 5) 버스 운행시간과 거리

# %%
a['distance'].mean()
# Out:
# 181.05179282868525

# %%
pd.concat([b,c,d,e])['distance'].mean()
# Out:
# 494.36649718819814

# %%
x = ['운행시간<20', '운행시간>=20']
y = [a['distance'].mean(), pd.concat([b,c,d,e])['distance'].mean()]

plt.figure(dpi=150)

plt.title('운행시간 vs 거리')
plt.xlabel('운행시간')
plt.ylabel('거리')

plt.bar(x,y)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50868 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54665 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44036 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44144 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47532 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 50868 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 54665 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44036 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44144 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 47532 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
b['distance'].mean()
# Out:
# 449.89411329137357

# %%
c['distance'].mean()
# Out:
# 2336.6912866623848

# %%
x = ['20~250', '250~600']
y = [b['distance'].mean(), c['distance'].mean()]

plt.figure(dpi=150)

plt.title('운행시간 vs 거리')
plt.xlabel('운행시간')
plt.ylabel('거리')

plt.bar(x,y)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50868 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54665 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44036 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44144 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47532 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 50868 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 54665 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44036 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44144 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 47532 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
import matplotlib.patches as patches

x = train['distance']
y = train['next_arrive_time']

plt.figure(dpi = 150)

plt.title('거리 vs 운행시간')
plt.xlabel('거리')
plt.ylabel('운행시간')

plt.scatter(x,y, alpha = 0.3)

plt.gca().add_patch(
   patches.Rectangle(
      (0, 600),
      1000, 2600,               
      edgecolor = 'deeppink',
      fill=False,
   ))

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44144 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47532 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50868 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54665 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44036 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44144 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 47532 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 50868 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 54665 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44036 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ### 6) 거리는 짧은데 운행시간은 긴 데이터

# %%
train[(train['distance'] < 1000) & (train['next_arrive_time'] > 600)]
# Out:
#             id        date   route_id    vh_id  route_nm  now_latitude  \
# 1785      1785  2019-10-15  405136002  7997043         1     33.458900
# 1840      1840  2019-10-15  405136002  7997082         1     33.458900
# 1997      1997  2019-10-15  405136002  7997082         1     33.477560
# 2003      2003  2019-10-15  405136002  7997082         1     33.458900
# 2113      2113  2019-10-15  405136002  7997111         1     33.477560
# ...        ...         ...        ...      ...       ...           ...
# 199675  199675  2019-10-28  405136521  7997089         4     33.476401
# 199818  199818  2019-10-28  405136522  7997002         5     33.502112
# 200069  200069  2019-10-28  405136522  7997032         5     33.476533
# 201187  201187  2019-10-28  405136522  7997107         5     33.458783
# 201229  201229  2019-10-28  405136522  7997110         5     33.481317
#
#         now_longitude  now_station  now_arrive_time  distance  next_station  \
# 1785       126.557300          370                7     435.0           371
# 1840       126.557300          370                5     435.0           371
# 1997       126.477406          427               16     518.0           428
# 2003       126.557300          370               17     435.0           371
# 2113       126.477406          427               12     518.0           428
# ...               ...          ...              ...       ...           ...
# 199675     126.479759          442               19     431.0           443
# 199818     126.527961          450               16     253.0           449
# 200069     126.544283          396                6     355.0           403
# 201187     126.557353          370               18     415.0           371
# 201229     126.473300          451                6     496.0           719
#
#         next_latitude  next_longitude  next_arrive_time
# 1785        33.460114      126.561659              2082
# 1840        33.460114      126.561659              1372
# 1997        33.476260      126.481417               668
# 2003        33.460114      126.561659              2906
# 2113        33.476260      126.481417               862
# ...               ...             ...               ...
# 199675      33.477787      126.475740              1428
# 199818      33.504099      126.526639              2112
# 200069      33.479705      126.543811               980
# 201187      33.459893      126.561624              2874
# 201229      33.478329      126.475118              1392
#
# [372 rows x 14 columns]

# %% [markdown]
# - 도심 또는 제주대학교

# %%
import folium

locations = train[(train['distance'] < 1000) & (train['next_arrive_time'] > 600)][['next_latitude',	'next_longitude']].values

m = folium.Map(location=center, zoom_start=11, tiles='cartodbpositron')

for location in locations:
  folium.Circle(
      radius=300,
      location=location,
      fill=True
  ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#         initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#     &lt;style&gt;#map_793df5f37119b1f4e5c0ec1690b7c3e0 {
#         position: relative;
#         width: 100.0%;
#         height: 100.0%;
#         left: 0.0%;
#         top: 0.0%;
#         }
#     &lt;/style&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div class=&quot;folium-map&quot; id=&quot;map_793df5f37119b1f4e5c0ec1690b7c3e0&quot; &gt;&lt;/div&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#         var bounds = null;
#
#
#     var map_793df5f37119b1f4e5c0ec1690b7c3e0 = L.map(
#         &#x27;map_793df5f37119b1f4e5c0ec1690b7c3e0&#x27;, {
#         center: [33.35, 126.5],
#         zoom: 11,
#         maxBounds: bounds,
#         layers: [],
#         worldCopyJump: false,
#         crs: L.CRS.EPSG3857,
#         zoomControl: true,
#         });
#
#
#
#     var tile_layer_d7d7a4e1c7336564ffa19d1ce3db3cd3 = L.tileLayer(
#         &#x27;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&#x27;,
#         {
#         &quot;attribution&quot;: null,
#         &quot;detectRetina&quot;: false,
#         &quot;maxNativeZoom&quot;: 18,
#         &quot;maxZoom&quot;: 18,
#         &quot;minZoom&quot;: 0,
#         &quot;noWrap&quot;: false,
#         &quot;opacity&quot;: 1,
#         &quot;subdomains&quot;: &quot;abc&quot;,
#         &quot;tms&quot;: false
# }).addTo(map_793df5f37119b1f4e5c0ec1690b7c3e0);
#
#
#             var circle_6dbe4392590621bdc7944a34242a448b = L.circle(
#                 [33.460114000000004, 126.561659],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 300,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_793df5f37119b1f4e5c0ec1690b7c3e0);
#
#
#
#             var circle_d03bc6d2cc9a69a0f187b29e0c78f0c6 = L.circle(
#                 [33.460114000000004, 126.561659],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 300,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_793df5f37119b1f4e5c0ec1690b7c3e0);
#
#
#
#             var circle_9c8cb2d65d3fa77e3d8227f0e079877c = L.circle(
#                 [33.47626, 126.481417],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 300,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_793df5f37119b1f4e5c0ec1690b7c3e0);
#
#
#
#             var circle_450ebfcfdc70ac218f4fd179d69cff35 = L.circle(
#                 [33.460114000000004, 126.561659],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 300,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_793df5f37119b1f4e5c0ec1690b7c3e0);
#
#
#
#             var circle_c1d8e8e597966ca740b7d7f3fa459d02 = L.circle(
#                 [33.47626, 126.481417],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 300,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_793df5f37119b1f4e5c0ec1690b7c3e0);
#
#
#
#             var circle_959d215c33506b7346ace511684f515d = L.circle(
#                 [33.47626, 126.481417],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 300,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_793df5f37119b1f4e5c0ec1690b7c3e0);
#
#
#
#             var circle_9c2e2f856643f3132443b61744fab072 = L.circle(
#                 [33.47626, 126.481417],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;

# %%
temp = train[(train['distance'] >= 1000) | (train['next_arrive_time'] <= 600)]

x = temp['distance']
y = temp['next_arrive_time']

plt.figure(dpi = 150)
plt.scatter(x,y, alpha = 0.3)

plt.gca().add_patch(
   patches.Ellipse(
      (4000, 600),
      8000, 800,               
      edgecolor = 'deeppink',
      fill=False,
      angle=3
   ))

plt.show()

# %% [markdown]
# ### 7) 극도로 오래 걸린 데이터

# %%
train = pd.read_csv('/content/drive/MyDrive/Dacon/6w 버스예측 pbl/train.csv')
test = pd.read_csv('/content/drive/MyDrive/
# 155666  제주여자중고등학교(광양방면)      33.485199      126.542896              2528
# 157456             정존마을      33.481317      126.473300              2456
# 157587            제대아파트      33.458783      126.557353              2644
# 158593             한라병원      33.489633      126.486000              2882
# 170888            제주대학교      33.460114      126.561659              2336
# 184859             제대마을      33.457848      126.553938              2456
# 185245            제대아파트      33.458900      126.557300              2308
# 198785    제주고등학교/중흥S클래스      33.476260      126.481417              2418
# 201187            제주대학교      33.459893      126.561624              2874

# %%
locations = train[train['next_arrive_time'] > 2300][['next_latitude',	'next_longitude']].values

center = [((train[['now_latitude',	'now_longitude']].loc[1].values[0])+(train[['now_latitude',	'now_longitude']].loc[len(train)-1].values[0]))/2, 
          ((train[['now_latitude',	'now_longitude']].loc[1].values[1])+(train[['now_latitude',	'now_longitude']].loc[len(train)-1].values[1]))/2]

m = folium.Map(location=center, zoom_start=11)

for location in locations:
  folium.Circle(
      radius=300,
      location=location,
      fill=True
  ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#         initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#     &lt;style&gt;#map_6f311e0940aaa7796c1ffdfebf68c762 {
#         position: relative;
#         width: 100.0%;
#         height: 100.0%;
#         left: 0.0%;
#         top: 0.0%;
#         }
#     &lt;/style&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div class=&quot;folium-map&quot; id=&quot;map_6f311e0940aaa7796c1ffdfebf68c762&quot; &gt;&lt;/div&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#         var bounds = null;
#
#
#     var map_6f311e0940aaa7796c1ffdfebf68c762 = L.map(
#         &#x27;map_6f311e0940aaa7796c1ffdfebf68c762&#x27;, {
#         center: [33.3531055, 126.53260449999999],
#         zoom: 11,
#         maxBounds: bounds,
#         layers: [],
#         worldCopyJump: false,
#         crs: L.CRS.EPSG3857,
#         zoomControl: true,
#         });
#
#
#
#     var tile_layer_b9edd791b0788e7d03b570fe79200108 = L.tileLayer(
#         &#x27;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&#x27;,
#         {
#         &quot;attribution&quot;: null,
#         &quot;detectRetina&quot;: false,
#         &quot;maxNativeZoom&quot;: 18,
#         &quot;maxZoom&quot;: 18,
#         &quot;minZoom&quot;: 0,
#         &quot;noWrap&quot;: false,
#         &quot;opacity&quot;: 1,
#         &quot;subdomains&quot;: &quot;abc&quot;,
#         &quot;tms&quot;: false
# }).addTo(map_6f311e0940aaa7796c1ffdfebf68c762);
#
#
#             var circle_9e6f291a7558a830b9c26b3c4f6f386d = L.circle(
#                 [33.460114000000004, 126.561659],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 300,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_6f311e0940aaa7796c1ffdfebf68c762);
#
#
#
#             var circle_816b13da71c1de20100a26dcc97ace0f = L.circle(
#                 [33.460114000000004, 126.561659],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 300,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_6f311e0940aaa7796c1ffdfebf68c762);
#
#
#
#             var circle_8116196ef4b49180746e1bd31d742812 = L.circle(
#                 [33.460114000000004, 126.561659],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 300,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_6f311e0940aaa7796c1ffdfebf68c762);
#
#
#
#             var circle_7000667ec52af69c5fbe446d1e4ec979 = L.circle(
#                 [33.460114000000004, 126.561659],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 300,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_6f311e0940aaa7796c1ffdfebf68c762);
#
#
#
#             var circle_65b38ca14faba63fb63c9cde3fe7ba34 = L.circle(
#                 [33.4589, 126.5573],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 300,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_6f311e0940aaa7796c1ffdfebf68c762);
#
#
#
#             var circle_cc0e9b28175942810e6e17198b35204e = L.circle(
#                 [33.460114000000004, 126.561659],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 300,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_6f311e0940aaa7796c1ffdfebf68c762);
#
#
#
#             var circle_8d2a3b525a98311f1e246557b93d6a21 = L.circle(
#                 [33.458783000000004, 126.557353],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,

# %%
train[(train['next_station'] == '제주대학교')]
# Out:
#             id        date   route_id    vh_id route_nm  now_latitude  \
# 2            2  2019-10-15  405136001  7997025    360-1     33.458783
# 35          35  2019-10-15  405136001  7997025    360-1     33.458783
# 103        103  2019-10-15  405136001  7997025    360-1     33.458783
# 141        141  2019-10-15  405136001  7997025    360-1     33.458783
# 180        180  2019-10-15  405136001  7997025    360-1     33.458783
# ...        ...         ...        ...      ...      ...           ...
# 201063  201063  2019-10-28  405136522  7997095   365-22     33.458783
locations = [train[(train['next_station'] == '제주대학교')][['next_latitude',	'next_longitude']].iloc[0].values, train[(train['next_station'] == '제주대학교') & (train['next_arrive_time'] > 300)][['next_latitude',	'next_longitude']].iloc[0].values]

center = [((train[['now_latitude',	'now_longitude']].loc[1].values[0])+(train[['now_latitude',	'now_longitude']].loc[len(train)-1].values[0]))/2, 
          ((train[['now_latitude',	'now_longitude']].loc[1].values[1])+(train[['now_latitude',	'now_longitude']].loc[len(train)-1].values[1]))/2]

m = folium.Map(location=center, zoom_start=11, tiles='cartodbpositron')

for i, location in enumerate(locations):
  folium.Circle(
      radius=10,
      location=location,
      tooltip=i,
      fill=True
  ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#         initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#     &lt;style&gt;#map_57e8110b1ddfc35f108b348db8b74d37 {
#         position: relative;
#         width: 100.0%;
#         height: 100.0%;
#         left: 0.0%;
#         top: 0.0%;
#         }
#     &lt;/style&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div class=&quot;folium-map&quot; id=&quot;map_57e8110b1ddfc35f108b348db8b74d37&quot; &gt;&lt;/div&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#         var bounds = null;
#
#
#     var map_57e8110b1ddfc35f108b348db8b74d37 = L.map(
#         &#x27;map_57e8110b1ddfc35f108b348db8b74d37&#x27;, {
#         center: [33.3531055, 126.53260449999999],
#         zoom: 11,
#         maxBounds: bounds,
#         layers: [],
#         worldCopyJump: false,
#         crs: L.CRS.EPSG3857,
#         zoomControl: true,
#         });
#
#
#
#     var tile_layer_bf478d85465b6ba15e629a2ecd536975 = L.tileLayer(
#         &#x27;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&#x27;,
#         {
#         &quot;attribution&quot;: null,
#         &quot;detectRetina&quot;: false,
#         &quot;maxNativeZoom&quot;: 18,
#         &quot;maxZoom&quot;: 18,
#         &quot;minZoom&quot;: 0,
#         &quot;noWrap&quot;: false,
#         &quot;opacity&quot;: 1,
#         &quot;subdomains&quot;: &quot;abc&quot;,
#         &quot;tms&quot;: false
# }).addTo(map_57e8110b1ddfc35f108b348db8b74d37);
#
#
#             var circle_bcfeba1aafd82c5fec38b65944c820b6 = L.circle(
#                 [33.459893, 126.561624],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 10,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_57e8110b1ddfc35f108b348db8b74d37);
#
#
#         circle_bcfeba1aafd82c5fec38b65944c820b6.bindTooltip(
#             `&lt;div&gt;`
#             + `0` + `&lt;/div&gt;`,
#             {&quot;sticky&quot;: true}
#         );
#
#
#
#             var circle_4016f08b848c0d9b6a2545e219e10bbf = L.circle(
#                 [33.460114000000004, 126.561659],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 10,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_57e8110b1ddfc35f108b348db8b74d37);
#
#
#         circle_4016f08b848c0d9b6a2545e219e10bbf.bindTooltip(
#             `&lt;div&gt;`
#             + `1` + `&lt;/div&gt;`,
#             {&quot;sticky&quot;: true}
#         );
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# - 좌표로도 오래 걸리는 데이터는 예측이 불가능

# %%
train[train['next_longitude'] == 126.561659]['next_arrive_time'].reset_index(drop=True).plot()

# %% [markdown]
# ## 5.이상치 예측 가능 여부 판단

# %%
model = RandomForestRegressor()

model.fit(X_train, y_train)

y_pred = model.predict(X_valid)

# %%
RMSE = rmse(y_pred, y_valid)

plt.figure(dpi=150)

plt.title('RMSE : ' + str(RMSE)[:8])

plt.plot(y_valid.reset_index(drop=True), alpha=0.6, label='real')
plt.plot(y_pred, alpha=0.6, label='pred')

plt.legend()
plt.show()

# %%
train = transform_df(train)
test = transform_df(test)

# %%
train = train[train[target] <= 1000]

# %%
X = train[features]
y = train[target]

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X,y, test_size=0.1, shuffle=False)

# %%
model = RandomForestRegressor()

model.fit(X_train, y_train)

y_pred = model.predict(X_valid)

# %%
RMSE = rmse(y_pred, y_valid)

plt.figure(dpi=150)

plt.title('RMSE : ' + str(RMSE)[:8])

plt.plot(y_valid.reset_index(drop=True), alpha=0.6, label='real')
plt.plot(y_pred, alpha=0.6, label='pred')

plt.legend()
plt.show()

# %% [markdown]
# ## 6.이상치 제거 모델로 제출

# %%
X = train[features]
y = train[target]

# %%
model = RandomForestRegressor()

model.fit(X, y)

y_pred = model.predict(test[features])

# %%
submission[target] = y_pred
submission.to_csv('submission.csv', index=False)
