# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('/content/drive/MyDrive/Dacon/3w 구내식당 식수예측/train.csv')
train.head(3)
# Out:
#            일자 요일  본사정원수  본사휴가자수  본사출장자수  본사시간외근무명령서승인건수  현본사소속재택근무자수  \
# 0  2016-02-01  월   2601      50     150             238          0.0
# 1  2016-02-02  화   2601      50     173             319          0.0
# 2  2016-02-03  수   2601      56     180             111          0.0
#
#                                                 조식메뉴  \
# 0  모닝롤/찐빵  우유/두유/주스 계란후라이  호두죽/쌀밥 (쌀:국내산) 된장찌개  쥐...
# 1  모닝롤/단호박샌드  우유/두유/주스 계란후라이  팥죽/쌀밥 (쌀:국내산) 호박젓국찌...
# 2  모닝롤/베이글  우유/두유/주스 계란후라이  표고버섯죽/쌀밥 (쌀:국내산) 콩나물국...
#
#                                                 중식메뉴  \
# 0  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 오징어찌개  쇠불고기 (쇠고기:호주산) 계란찜 ...
# 1  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 김치찌개  가자미튀김  모둠소세지구이  마늘쫑무...
# 2  카레덮밥 (쌀,현미흑미:국내산) 팽이장국  치킨핑거 (닭고기:국내산) 쫄면야채무침 ...
#
#                                                 석식메뉴     중식계    석식계
# 0  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 육개장  자반고등어구이  두부조림  건파래무침 ...  1039.0  331.0
# 1  콩나물밥*양념장 (쌀,현미흑미:국내산) 어묵국  유산슬 (쇠고기:호주산) 아삭고추무...   867.0  560.0
# 2  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 청국장찌개  황태양념구이 (황태:러시아산) 고기...  1017.0  573.0

# %%
submission = pd.read_csv('/content/drive/MyDrive/Dacon/3w 구내식당 식수예측/sample_submission.csv')
submission.head(3)
# Out:
#            일자  중식계  석식계
# 0  2021-01-27    0    0
# 1  2021-01-28    0    0
# 2  2021-01-29    0    0

# %%
submission['중식계'] == train['중식계'].mean()

submission['석식계']== train['석식계'].mean()

submission.to_csv('submission.csv',index=False)
submission.head(3)
# Out:
#            일자  중식계  석식계
# 0  2021-01-27    0    0
# 1  2021-01-28    0    0
# 2  2021-01-29    0    0

# %%
pwd
# Out:
# '/content'

# %%
test = pd.read_csv('/content/drive/MyDrive/Dacon/3w 구내식당 식수예측/test.csv')

# %%
features = ['본사정원수',	'본사휴가자수',	'본사출장자수',	'본사시간외근무명령서승인건수',	'현본사소속재택근무자수'	]
X = train[features]
y = train['중식계']

lunch_model = DecisionTreeRegressor()

lunch_model.fit(X,y)

lunch_count.predict = lunch_model.predict(test[features])

pd.DataFrame(lunch_count_predict)

plt.plot(lunch_count_predict)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-4350c3a6f913> in <module>()
#       7 lunch_model.fit(X,y)
#       8
# ----> 9 lunch_count.predict = lunch_model.predict(test[features])
#      10
#      11 pd.DataFrame(lunch_count_predict)
#
# NameError: name 'lunch_count' is not defined

# %% [markdown]
# # 2) 모델 정의

# %%
from sklearn.tree import DecisionTreeRegressor

lunch_model = DecisionTreeRegressor()

# %% [markdown]
# # 3) 모델 학습

# %%
lunch_model.fit(X,y)
# Out:
# DecisionTreeRegressor()

# %% [markdown]
# # 4) 예측

# %%
lunch_count_predict = lunch_model.predict(test[features])
lunch_count_predict
plt.plot(lunch_count_predict)
plt.show()

# %%
X = train[features]
y = train['석식계']

dinner_model = DecisionTreeRegressor()

dinner_model.fit(X,y)

dinner_count_predict = dinner_model.predict(test[features])

pd.DataFrame(dinner_count_predict)

plt.plot(dinner_count_predict)
plt.show()

# %%
from sklearn import tree
plt.figure(dpi = 150)

tree.plot_tree(dinner_model)
# plt.savefig('이미지이름 : 영어로',dpi = 150)
plt.show()

# %%
submission['중식계'] = lunch_count_predict
submission['석식계'] = dinner_count_predict
submission.to_csv('submission_meal.csv', index = False)

# %% [markdown]
# # 식수 예측 3 - EDA

# %% [markdown]
# ## 1) target을 주인공으로

# %%
plt.figure(dpi = 150)

plt.title('일별 중식계')
plt.xlabel('일')
plt.ylabel('중식계')

plt.plot(train.index)
